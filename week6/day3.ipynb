# %% [markdown]
# # The Product Pricer Continued
#
# A model that can estimate how much something costs, from its description.
#
# ## Baseline Models
#
# Today we work on the simplest models to act as a starting point that we will beat.

# %%
# imports

import os
import math
import json
import random
from dotenv import load_dotenv
from huggingface_hub import login
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter

# %%
# More imports for our traditional machine learning

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## NLP imports
#
# In the next cell, we have more imports for our NLP related machine learning.
# If the gensim import gives you an error like "Cannot import name 'triu' from 'scipy.linalg' then please run in another cell:
# `!pip install "scipy<1.13"`
# As described on StackOverflow [here](https://stackoverflow.com/questions/78279136/importerror-cannot-import-name-triu-from-scipy-linalg-when-importing-gens).
# Many thanks to students Arnaldo G and Ard V for sorting this.

# %%
# NLP related imports

from sklearn.feature_extraction.text import CountVectorizer
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

# %%
# Finally, more imports for more advanced machine learning

from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Constants - used for printing to stdout in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
# Log in to HuggingFace

hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Token has not been saved to git credential helper.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.

# %%
# One more import after logging in

from items import Item

# %%
# %matplotlib inline

# %% [markdown]
# # Loading the pkl files
#
# Let's avoid curating all our data again! Load in the pickle files
#
# If you didn't already create these in Day 2, you can also download them from my google drive (you'll also find the slides here):
# https://drive.google.com/drive/folders/1JwNorpRHdnf_pU0GE5yYtfKlyrKC3CoV?usp=sharing
#
# But note that the files are quite large - you might need to get a coffee!

# %%
with open('train.pkl', 'rb') as file:
    train = pickle.load(file)

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
print(train[0].test_prompt())
# Out:
# How much does this cost to the nearest dollar?
#
# Delphi FG0166 Fuel Pump Module
# Delphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7
#
# Price is $

# %%
# Remind ourselves the training prompt

print(train[0].prompt)
# Out:
# How much does this cost to the nearest dollar?
#
# Delphi FG0166 Fuel Pump Module
# Delphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7
#
# Price is $227.00

# %%
# Remind a test prompt

print(train[0].price)
# Out:
# 226.95

# %% [markdown]
# ## Unveiling a mighty script that we will use a lot!
#
# A rather pleasing Test Harness that will evaluate any model against 250 items from the Test set
#
# And show us the results in a visually satisfying way.
#
# You write a function of this form:
#
# ```
# def my_prediction_function(item):
#     # my code here
#     return my_estimate
# ```
#
# And then you call:
#
# `Tester.test(my_prediction_function)`
#
# To evaluate your model.

# %%
class Tester:

    def __init__(self, predictor, title=None, data=test, size=250):
        self.predictor = predictor    # 加载预测模型
        self.data = data    # 加载测试数据
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"
    
    def run_datapoint(self, i):  # 对单个数据点进行预测和评估
        datapoint = self.data[i]
        guess = self.predictor(datapoint)  # 调用预测模型进行价格预测
        truth = datapoint.price
        error = abs(guess - truth)   # 评估误差 绝对误差
        log_error = math.log(truth+1) - math.log(guess+1)   # +1 防止log(0)爆炸
        sle = log_error ** 2   # 评估误差 平方对数误差
        color = self.color_for(error, truth)
        title = datapoint.title if len(datapoint.title) <= 40 else datapoint.title[:40]+"..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size   # 平均误差
        rmsle = math.sqrt(sum(self.sles) / self.size)   # 均方对数误差
        hits = sum(1 for color in self.colors if color=="green")  # 命中次数（准确率）
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function):
        cls(function).run()

# %% [markdown]
# # Now for something basic
#
# What's the very simplest model you could imagine?
#
# Let's start with a random number generator!

# %%
def random_pricer(item):
    return random.randrange(1,1000)

# %%
# Set the random seed

random.seed(42)

# Run our TestRunner
Tester.test(random_pricer)  # 随机数作为predictor（其实是在胡乱预测）
# Out:
# 1: Guess: $655.00 Truth: $374.41 Error: $280.59 SLE: 0.31 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $115.00 Truth: $225.11 Error: $110.11 SLE: 0.45 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $26.00 Truth: $61.68 Error: $35.68 SLE: 0.71 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $760.00 Truth: $599.99 Error: $160.01 SLE: 0.06 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $282.00 Truth: $16.99 Error: $265.01 SLE: 7.59 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $251.00 Truth: $31.99 Error: $219.01 SLE: 4.13 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $229.00 Truth: $101.79 Error: $127.21 SLE: 0.65 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $143.00 Truth: $289.00 Error: $146.00 SLE: 0.49 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $755.00 Truth: $635.86 Error: $119.14 SLE: 0.03 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
# That was fun!
# We can do better - here's another rather trivial model

training_prices = [item.price for item in train]
training_average = sum(training_prices) / len(training_prices)

def constant_pricer(item):
    return training_average

# %%
# Run our constant predictor
Tester.test(constant_pricer)  # 把平均数作为全部的预测值
# Out:
# 1: Guess: $220.46 Truth: $374.41 Error: $153.95 SLE: 0.28 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $220.46 Truth: $225.11 Error: $4.65 SLE: 0.00 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $220.46 Truth: $61.68 Error: $158.78 SLE: 1.59 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $220.46 Truth: $599.99 Error: $379.53 SLE: 1.00 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $220.46 Truth: $16.99 Error: $203.47 SLE: 6.30 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $220.46 Truth: $31.99 Error: $188.47 SLE: 3.63 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $220.46 Truth: $101.79 Error: $118.67 SLE: 0.59 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $220.46 Truth: $289.00 Error: $68.54 SLE: 0.07 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $220.46 Truth: $635.86 Error: $415.40 SLE: 1.12 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
train[0].details
# Out:
# '{"Brand": "Delphi", "Fit Type": "Vehicle Specific Fit", "Item Dimensions LxWxH": "19.7 x 7.7 x 5.1 inches", "Item Weight": "2.2 Pounds", "Auto Part Position": "Unknown", "Operation Mode": "Mechanical", "Manufacturer": "Delphi", "Model": "FUEL PUMP", "Product Dimensions": "19.7 x 7.7 x 5.1 inches", "Country of Origin": "USA", "Item model number": "FG0166", "Is Discontinued By Manufacturer": "No", "Exterior": "Painted", "Manufacturer Part Number": "FG0166", "OEM Part Number": "25326856, 89060639, A30416, E4061R, MU242", "Best Sellers Rank": {"Automotive": 913571, "Automotive Replacement Electric Fuel Pumps": 6568}, "Domestic Shipping": "Item can be shipped within U.S.", "International Shipping": "This item is not eligible for international shipping.  Learn More", "Date First Available": "August 9, 2006"}'

# %%
# Create a new "features" field on items, and populate it with json parsed from the details dict
# 物品的哪些特性对预测其价格最有意义？
for item in train:
    item.features = json.loads(item.details)
for item in test:
    item.features = json.loads(item.details)

# Look at one

# %%
train[0].features.keys()  # 物品的哪些特性对预测其价格最有意义？
# Out:
# dict_keys(['Brand', 'Fit Type', 'Item Dimensions LxWxH', 'Item Weight', 'Auto Part Position', 'Operation Mode', 'Manufacturer', 'Model', 'Product Dimensions', 'Country of Origin', 'Item model number', 'Is Discontinued By Manufacturer', 'Exterior', 'Manufacturer Part Number', 'OEM Part Number', 'Best Sellers Rank', 'Domestic Shipping', 'International Shipping', 'Date First Available'])

# %%
# Look at 20 most common features in training set

feature_count = Counter()
for item in train:
    for f in item.features.keys():
        feature_count[f]+=1

feature_count.most_common(40)
# Out:
# [('Date First Available', 360062),
#  ('Item Weight', 350444),
#  ('Manufacturer', 349357),
#  ('Brand', 340323),
#  ('Best Sellers Rank', 330473),
#  ('Item model number', 277573),
#  ('Product Dimensions', 262400),
#  ('Color', 183794),
#  ('Is Discontinued By Manufacturer', 169828),
#  ('Manufacturer Part Number', 145092),
#  ('Material', 137447),
#  ('Country of Origin', 121451),
#  ('Style', 77639),
#  ('Special Feature', 74709),
#  ('Part Number', 74529),
#  ('Batteries Required?', 73595),
#  ('Package Dimensions', 72900),
#  ('Item Dimensions LxWxH', 71385),
#  ('Included Components', 67509),
#  ('Model', 65144),
#  ('Size', 58233),
#  ('Item Package Quantity', 58149),
#  ('Batteries Included?', 56779),
#  ('OEM Part Number', 56062),
#  ('Special Features', 53740),
#  ('Exterior', 50566),
#  ('Power Source', 50256),
#  ('Vehicle Service Type', 49420),
#  ('Finish Type', 46262),
#  ('Voltage', 46036),
#  ('Mounting Type', 38043),
#  ('Model Name', 37524),
#  ('Shape', 34816),
# ...

# %%
# Now some janky code to pluck out the Item Weight
# Don't worry too much about this: spoiler alert, it's not going to be much use in training!
# 统一重量单位
def get_weight(item):
    weight_str = item.features.get('Item Weight')
    if weight_str:
        parts = weight_str.split(' ')
        amount = float(parts[0])
        unit = parts[1].lower()
        if unit=="pounds":
            return amount
        elif unit=="ounces":
            return amount / 16
        elif unit=="grams":
            return amount / 453.592
        elif unit=="milligrams":
            return amount / 453592
        elif unit=="kilograms":
            return amount / 0.453592
        elif unit=="hundredths" and parts[2].lower()=="pounds":
            return amount / 100
        else:
            print(weight_str)
    return None

# %%
weights = [get_weight(t) for t in train]
weights = [w for w in weights if w]

# %%
average_weight = sum(weights)/len(weights)
average_weight
# Out:
# 13.57055237029551

# %%
# 如果没有weight，就用average weight替代
def get_weight_with_default(item):
    weight = get_weight(item)
    return weight or average_weight

# %%
def get_rank(item):
    rank_dict = item.features.get("Best Sellers Rank")  # 同个商品可能在不同的畅销列表中，所以返回的是dict
    if rank_dict:
        ranks = rank_dict.values()
        return sum(ranks)/len(ranks)  # 把在不同畅销列表中的排名平均一下，合成一个
    return None

# %%
ranks = [get_rank(t) for t in train]
ranks = [r for r in ranks if r]
average_rank = sum(ranks)/len(ranks)  # 获得average rank
average_rank
# Out:
# 380638.258828069

# %%
def get_rank_with_default(item):
    rank = get_rank(item)
    return rank or average_rank  # 如果没有rank，就用average rank替代

# %%
# 之前那张红色的散点图表明，prompt的长度也和价格有一定的相关性(应该是商品描述的长度)
def get_text_length(item):
    return len(item.test_prompt())

# %%
# investigate the brands

brands = Counter()
for t in train:
    brand = t.features.get("Brand")
    if brand:
        brands[brand]+=1

# Look at most common 40 brands

brands.most_common(40)
# Out:
# [('HP', 5500),
#  ('Power Stop', 3594),
#  ('Dell', 3254),
#  ('Detroit Axle', 2734),
#  ('Lenovo', 2441),
#  ('Dorman', 2116),
#  ('SAMSUNG', 1772),
#  ('BUYAUTOPARTS!', 1715),
#  ('ACDelco', 1609),
#  ('Evan Fischer', 1415),
#  ('ASUS', 1387),
#  ('Sony', 1282),
#  ('Canon', 1201),
#  ('Callahan BRAKE PARTS', 1154),
#  ('Kohler', 1152),
#  ('CURT', 1120),
#  ('R1 Concepts', 1054),
#  ('Rareelectrical', 966),
#  ('Coverking', 941),
#  ('Garage-Pro', 888),
#  ('Kingston Brass', 852),
#  ('Spectra Premium', 834),
#  ('Moen', 829),
#  ('Auto Dynasty', 824),
#  ('WeatherTech', 822),
#  ('DELTA FAUCET', 811),
#  ('Generic', 793),
#  ('Apple', 783),
#  ('Cardone', 765),
#  ('APS', 763),
#  ('K&N', 758),
#  ('GM', 743),
#  ('Walker', 732),
#  ('EBC Brakes', 717),
#  ('AKKON', 646),
#  ('SPEC-D TUNING', 626),
#  ('TYC', 626),
#  ('Covercraft', 618),
#  ('Intel', 610),
#  ('A-Premium', 607)]

# %%
# ... existing code ...

def brand_exists(data, target_brand):
    """检查品牌是否存在于数据集中"""
    target = target_brand.lower()
    for item in data:
        brand = item.features.get("Brand")
        if brand and brand.lower() == target:
            return True
    return False

# 使用示例：检查是否存在
brand_exists(train, "steinberg")
# Out:
# True

# %%
# 因为作者本人对电子产品比较了解，所以明白电子产品的价格和品牌有关
# 所以先提取电子产品的相关品牌
# 也可以自己试试有没有别的可能的相关性特征
TOP_ELECTRONICS_BRANDS = ["hp", "dell", "lenovo", "samsung", "asus", "sony", "canon", "apple", "intel", "lg", "nikon", "fujifilm", "anker"]  
def is_top_electronics_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_ELECTRONICS_BRANDS

# %%
TOP_AUTOMOTIVE_BRANDS = ["bosch", "mobil 1", "michelin", "3m", "armor all", "k&n"]  
def is_top_automotive_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_AUTOMOTIVE_BRANDS

# %%
TOP_OFFICE_PRODUCTS_BRANDS = ["hp", "canon", "brother", "3m", "fellowes", "logitech"] 
def is_top_office_products_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_OFFICE_PRODUCTS_BRANDS

# %%
TOP_TOOLS_AND_HOME_IMPROVEMENT_BRANDS = ["dewalt", "bosch", "makita", "ring", "philips hue", "honeywell"]
def is_top_hometools_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_TOOLS_AND_HOME_IMPROVEMENT_BRANDS

# %%
TOP_CELL_PHONES_AND_ACCESSORIES_BRANDS = ["apple", "samsung", "huawei", "xiaomi", "oppo", "vivo", "anker", "spigen", "otterbox", "belkin", "popsockets"]
def is_top_cellphones_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_CELL_PHONES_AND_ACCESSORIES_BRANDS

# %%
TOP_TOYS_AND_GAMES_BRANDS = ["lego", "mattel", "hasbro", "fisher-price", "nintendo", "melissa & doug"]
def is_top_toys_and_games_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_TOYS_AND_GAMES_BRANDS

# %%
TOP_APPLIANCES_BRANDS = ["whirlpool", "ge appliances", "dyson", "kitchenaid", "instant pot", "panasonic", "lg", "samsung", "kohler"]
def is_top_appliances_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_APPLIANCES_BRANDS

# %%
TOP_MUSICAL_INSTRUMENTS_BRANDS = ["yamaha", "fender", "gibson", "roland", "casio", "shure", "audio-technica", "steinberg"]
def is_top_musical_instruments_brand(item):
    brand = item.features.get("Brand")
    return brand and brand.lower() in TOP_MUSICAL_INSTRUMENTS_BRANDS

# %%
def get_features(item):
    return {
        "weight": get_weight_with_default(item),
        "rank": get_rank_with_default(item),
        "text_length": get_text_length(item),
        "is_top_electronics_brand": 1 if is_top_electronics_brand(item) else 0,
        "is_top_automotive_brand" : 1 if is_top_automotive_brand(item) else 0,
        "is_top_office_products_brand" : 1 if is_top_office_products_brand(item) else 0,
        "is_top_hometools_brand": 1 if is_top_hometools_brand(item) else 0,
        "is_top_appliances_brand" : 1 if is_top_appliances_brand(item) else 0,
        "is_top_cellphones_brand": 1 if is_top_cellphones_brand(item) else 0,
        "is_top_toys_and_games_brand" : 1 if is_top_toys_and_games_brand(item) else 0,
        "is_top_musical_instruments_brand" : 1 if is_top_musical_instruments_brand(item) else 0,
    }

# %%
# Look at features in a training item
get_features(train[0])
# Out:
# {'weight': 2.2,
#  'rank': 460069.5,
#  'text_length': 748,
#  'is_top_electronics_brand': 0,
#  'is_top_automotive_brand': 0,
#  'is_top_office_products_brand': 0,
#  'is_top_hometools_brand': 0,
#  'is_top_appliances_brand': 0,
#  'is_top_cellphones_brand': 0,
#  'is_top_toys_and_games_brand': 0,
#  'is_top_musical_instruments_brand': 0}

# %%
# A utility function to convert our features into a pandas dataframe

def list_to_dataframe(items):
    features = [get_features(item) for item in items]
    df = pd.DataFrame(features)
    df['price'] = [item.price for item in items]
    return df

train_df = list_to_dataframe(train)
test_df = list_to_dataframe(test[:250])

# %%
# Traditional Linear Regression!

np.random.seed(42)

# Separate features and target
feature_columns = ['weight', 'rank', 'text_length', 'is_top_electronics_brand', 'is_top_automotive_brand', 'is_top_office_products_brand', 'is_top_hometools_brand', 'is_top_appliances_brand', 'is_top_cellphones_brand', 'is_top_toys_and_games_brand', 'is_top_musical_instruments_brand']

X_train = train_df[feature_columns]
y_train = train_df['price']
X_test = test_df[feature_columns]
y_test = test_df['price']

# Train a Linear Regression
model = LinearRegression()
model.fit(X_train, y_train)

for feature, coef in zip(feature_columns, model.coef_):
    print(f"{feature}: {coef}")
print(f"Intercept: {model.intercept_}")

# Predict the test set and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared Score: {r2}")
# Out:
# weight: 0.2602008959757378
# rank: 4.661127715407373e-05
# text_length: -0.028768658026813602
# is_top_electronics_brand: 91.31814912687976
# is_top_automotive_brand: -2.295516880387332
# is_top_office_products_brand: 91.31814912687996
# is_top_hometools_brand: 23.725125457100745
# is_top_appliances_brand: 86.29350467920509
# is_top_cellphones_brand: 59.00073420984173
# is_top_toys_and_games_brand: -84.01291262375442
# is_top_musical_instruments_brand: 163.43079377129143
# Intercept: 215.67018373104398
# Mean Squared Error: 35195.1592070992
# R-squared Score: 0.03145122992782534

# %%
# Function to predict price for a new item

def linear_regression_pricer(item):
    features = get_features(item)
    features_df = pd.DataFrame([features])
    return model.predict(features_df)[0]

# %%
# test it

Tester.test(linear_regression_pricer)
# Out:
# 1: Guess: $228.20 Truth: $374.41 Error: $146.21 SLE: 0.24 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $220.66 Truth: $225.11 Error: $4.45 SLE: 0.00 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $200.31 Truth: $61.68 Error: $138.63 SLE: 1.36 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $378.95 Truth: $599.99 Error: $221.04 SLE: 0.21 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $215.05 Truth: $16.99 Error: $198.06 SLE: 6.18 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $214.76 Truth: $31.99 Error: $182.77 SLE: 3.53 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $193.05 Truth: $101.79 Error: $91.26 SLE: 0.40 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $199.53 Truth: $289.00 Error: $89.47 SLE: 0.14 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $226.08 Truth: $635.86 Error: $409.78 SLE: 1.06 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
# For the next few models, we prepare our documents and prices
# Note that we use the test prompt for the documents, otherwise we'll reveal the answer!!
# 这里就和前面的features没关系了
prices = np.array([float(item.price) for item in train])
documents = [item.test_prompt() for item in train]

# %%
# Use the CountVectorizer for a Bag of Words model

np.random.seed(42)
vectorizer = CountVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(documents)
regressor = LinearRegression()
regressor.fit(X, prices)
# Out:
# LinearRegression()

# %%
def bow_lr_pricer(item):
    x = vectorizer.transform([item.test_prompt()])
    return max(regressor.predict(x)[0], 0)

# %%
# test it

Tester.test(bow_lr_pricer)
# Out:
# 1: Guess: $296.58 Truth: $374.41 Error: $77.83 SLE: 0.05 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $165.15 Truth: $225.11 Error: $59.96 SLE: 0.09 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $162.26 Truth: $61.68 Error: $100.58 SLE: 0.92 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $326.14 Truth: $599.99 Error: $273.85 SLE: 0.37 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $51.68 Truth: $16.99 Error: $34.69 SLE: 1.15 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $74.06 Truth: $31.99 Error: $42.07 SLE: 0.68 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $344.82 Truth: $101.79 Error: $243.03 SLE: 1.47 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $241.39 Truth: $289.00 Error: $47.61 SLE: 0.03 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $404.57 Truth: $635.86 Error: $231.29 SLE: 0.20 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
# The amazing word2vec model, implemented in gensim NLP library

np.random.seed(42)

# Preprocess the documents
processed_docs = [simple_preprocess(doc) for doc in documents]

# Train Word2Vec model
w2v_model = Word2Vec(sentences=processed_docs, vector_size=400, window=5, min_count=1, workers=8)

# %%
# This step of averaging vectors across the document is a weakness in our approach

def document_vector(doc):
    doc_words = simple_preprocess(doc)
    word_vectors = [w2v_model.wv[word] for word in doc_words if word in w2v_model.wv]
    return np.mean(word_vectors, axis=0) if word_vectors else np.zeros(w2v_model.vector_size)

# Create feature matrix
X_w2v = np.array([document_vector(doc) for doc in documents])

# %%
# Run Linear Regression on word2vec

word2vec_lr_regressor = LinearRegression()
word2vec_lr_regressor.fit(X_w2v, prices)
# Out:
# LinearRegression()

# %%
def word2vec_lr_pricer(item):
    doc = item.test_prompt()
    doc_vector = document_vector(doc)
    return max(0, word2vec_lr_regressor.predict([doc_vector])[0])

# %%
Tester.test(word2vec_lr_pricer)
# Out:
# 1: Guess: $245.48 Truth: $374.41 Error: $128.93 SLE: 0.18 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $172.25 Truth: $225.11 Error: $52.86 SLE: 0.07 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $147.50 Truth: $61.68 Error: $85.82 SLE: 0.74 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $359.45 Truth: $599.99 Error: $240.54 SLE: 0.26 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $105.87 Truth: $16.99 Error: $88.88 SLE: 3.17 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $0.00 Truth: $31.99 Error: $31.99 SLE: 12.22 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $308.62 Truth: $101.79 Error: $206.83 SLE: 1.22 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $259.11 Truth: $289.00 Error: $29.89 SLE: 0.01 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $330.51 Truth: $635.86 Error: $305.35 SLE: 0.43 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
# Support Vector Machines

np.random.seed(42)
svr_regressor = LinearSVR()
svr_regressor.fit(X_w2v, prices)
# Out:
# LinearSVR()

# %%
def svr_pricer(item):
    np.random.seed(42)
    doc = item.test_prompt()
    doc_vector = document_vector(doc)
    return max(float(svr_regressor.predict([doc_vector])[0]),0)

# %%
Tester.test(svr_pricer)
# Out:
# 1: Guess: $242.48 Truth: $374.41 Error: $131.93 SLE: 0.19 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $164.34 Truth: $225.11 Error: $60.77 SLE: 0.10 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $103.49 Truth: $61.68 Error: $41.81 SLE: 0.26 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $301.44 Truth: $599.99 Error: $298.55 SLE: 0.47 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $65.11 Truth: $16.99 Error: $48.12 SLE: 1.69 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $0.00 Truth: $31.99 Error: $31.99 SLE: 12.22 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $256.98 Truth: $101.79 Error: $155.19 SLE: 0.85 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $198.06 Truth: $289.00 Error: $90.94 SLE: 0.14 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $275.56 Truth: $635.86 Error: $360.30 SLE: 0.70 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...

# %%
# And the powerful Random Forest regression

rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=8)
rf_model.fit(X_w2v, prices)
# Out:
# RandomForestRegressor(n_jobs=8, random_state=42)

# %%
def random_forest_pricer(item):
    doc = item.test_prompt()
    doc_vector = document_vector(doc)
    return max(0, rf_model.predict([doc_vector])[0])

# %%
Tester.test(random_forest_pricer)
# Out:
# 1: Guess: $309.75 Truth: $374.41 Error: $64.66 SLE: 0.04 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $190.53 Truth: $225.11 Error: $34.58 SLE: 0.03 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $145.02 Truth: $61.68 Error: $83.34 SLE: 0.72 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $437.69 Truth: $599.99 Error: $162.30 SLE: 0.10 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $200.40 Truth: $16.99 Error: $183.41 SLE: 5.83 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $42.20 Truth: $31.99 Error: $10.21 SLE: 0.07 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $286.11 Truth: $101.79 Error: $184.32 SLE: 1.06 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $210.14 Truth: $289.00 Error: $78.86 SLE: 0.10 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $320.31 Truth: $635.86 Error: $315.55 SLE: 0.47 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# ...
